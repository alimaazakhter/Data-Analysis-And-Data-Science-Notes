# %%
import numpy as np

# %% [markdown]
# Basic Array Creation

# %%
arr = np.array([1,2,3,4,5])
(arr)
# Out:
# array([1, 2, 3, 4, 5])

# %%
a = [1,2,3,4,"Hello"]
a
# Out:
# [1, 2, 3, 4, 'Hello']

# %%
np.array(a)
# Out:
# array(['1', '2', '3', '4', 'Hello'], dtype='<U21')

# %%
l = [[1,2,3,], [4,5,6], [7,8,9]]
l
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
np.array(l)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 8, 9]])
